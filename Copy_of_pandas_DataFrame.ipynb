# %% [markdown]
# <a href="https://colab.research.google.com/github/jiraroj-wir/MUIC-ICCS261-Principles-of-Data-Science/blob/main/Copy_of_pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas - DataFrame
# *B. Mathayomchan and K. Bunchongchit*<br>
# Last edited on January 8, 2026
#
# ## Topics:
# What is a DataFrame?
#
# 1. CREATE
# 2. READ
# 3. UPDATE
# 4. DELETE

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## What is a DataFrame?
# DataFrame is a Data in a table form (like a spreadsheet) where all data points in the same column have the same type.
#
# <img src="https://pynative.com/wp-content/uploads/2021/02/dataframe.png" width=50% />

# %%
df = pd.DataFrame({
    'Gold': [15, 12, 10],
    'Silver': [11, 9, 5] ,
    'Bronze': [6, 8, 12],
    'Continent': ['Europe', 'Asia', 'Asia']
    },
    ['France','China','Thailand'])
df
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# ## 1. CREATE
# The simple way to create a dataframe from scratch is by using a dictionary. A dictionary holds key:value where **key** is column name. The **value** is a **list** of data points.
#
# <img src="https://av-eks-blogoptimized.s3.amazonaws.com/17699Append-a-Dictionary-to-a-list-in-Python-5-i2tutorials.png" />

# %%
my_dt = {
    'Gold': [15, 12, 10],
    'Silver': [11, 9, 5] ,
    'Bronze': [6, 8, 12],
    'Continent': ['Europe', 'Asia', 'Asia']
}
df1 = pd.DataFrame(my_dt)
df1
# Out:
#    Gold  Silver  Bronze Continent
# 0    15      11       6    Europe
# 1    12       9       8      Asia
# 2    10       5      12      Asia

# %% [markdown]
# Notice that the index of the row is a number. This is called **the label index**. As the word **label** may hint us already, we can set **the label index** to string as well.

# %%
my_list = ['France', 'China', 'Thailand']
df2 = pd.DataFrame(my_dt, my_list)
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# Create a dataframe by manually setting each column with a series.

# %%
df3 = pd.DataFrame()              # Start with empty dataframe
ser1 = pd.Series([15, 11, 6])     # Create a series from a list
ser2 = pd.Series([11, 9, 5])      # Create a series from a list
ser3 = pd.Series([10, 5, 2])      # Create a series from a list
ser4 = pd.Series(["Europe", "Asia", "Asia"])  # Create a series from a list

df3["Gold"] = ser1
df3["Silver"] = ser2
df3["Bronze"] = ser3
df3["Continent"] = ser4

df3
# Out:
#    Gold  Silver  Bronze Continent
# 0    15      11      10    Europe
# 1    11       9       5      Asia
# 2     6       5       2      Asia

# %%
my_index = pd.Series(["France", "China", "Thailand"])  # Create a series from a list
# inplace indicates Python to save the result into the caller variable
df33 = df3.set_index(my_index)
df33
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11      10    Europe
# China       11       9       5      Asia
# Thailand     6       5       2      Asia

# %%
df3
# Out:
#    Gold  Silver  Bronze Continent
# 0    15      11      10    Europe
# 1    11       9       5      Asia
# 2     6       5       2      Asia

# %%
# Create a series from a list
my_index = pd.Series(["France", "China", "Thailand"])
# inplace indicates Python to save the result into the caller variable
# df3 = df3.set_index(my_index)
df3.set_index(my_index, inplace=True)
df3
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11      10    Europe
# China       11       9       5      Asia
# Thailand     6       5       2      Asia

# %% [markdown]
# ## 2 READ
#     2.1 Subsetting columns
#         - Subsetting one column
#         - Subsetting multiple columns
#     2.2 Subsetting rows
#         - Subsetting rows when numbers are used as the label index
#         - Subsetting rows when labels are used as the label index
#     2.3 Subsetting both rows and columns
#     2.4 Accessing any particular element
#
# ### 2.1 Subsetting columns
# **Subsetting one column**: We can subset a column out by column name.
# ```
# df['column_name']
# ```

# %%
df3
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11      10    Europe
# China       11       9       5      Asia
# Thailand     6       5       2      Asia

# %%
df3['Continent']
# Out:
# France      Europe
# China         Asia
# Thailand      Asia
# Name: Continent, dtype: str

# %%
df3['Continent'].shape
# Out:
# (3,)

# %%
df3[['Continent']]
# Out:
#          Continent
# France      Europe
# China         Asia
# Thailand      Asia

# %%
print(type(df3['Continent']), type(df3[['Continent']]))
# Out:
# <class 'pandas.Series'> <class 'pandas.DataFrame'>

# %% [markdown]
# **Prompt**: What is the difference between ```df3['Continent']``` and ```df3[['Continent']]```?

# %%
print(df3)
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11      10    Europe
# China       11       9       5      Asia
# Thailand     6       5       2      Asia

# %% [markdown]
# **Prompt**: Which printing is the result of __str__ and which one __repr__?
#
#
# 1.   ```df3``` $\to$ `repr`
# 2.   ```print(df3)``` $\to$ `str`

# %% [markdown]
# **Subsetting multiple columns :** We can subset multiple columns by a list of column names.
# ```
# df[['col_name1', 'col_name2',..., 'col_namen']]
# ```

# %%
df1[['Gold', 'Continent']]
# Out:
#    Gold Continent
# 0    15    Europe
# 1    12      Asia
# 2    10      Asia

# %%
df1['Gold', 'Continent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: ('Gold', 'Continent')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df1['Gold', 'Continent']
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: ('Gold', 'Continent')

# %% [markdown]
# ### 2.2 Subsetting rows
# **Subsetting rows when numbers are used as the label index**
#
# We can use  **```loc['index_label']```** to subset the row.
#
# The **index labels** of df1 are numbers. We can subset the row by the numbers.

# %%
df1
# Out:
#    Gold  Silver  Bronze Continent
# 0    15      11       6    Europe
# 1    12       9       8      Asia
# 2    10       5      12      Asia

# %%
df1.loc[0]
# Out:
# Gold             15
# Silver           11
# Bronze            6
# Continent    Europe
# Name: 0, dtype: object

# %%
df1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df1[0]
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
type(df1.loc[0])
# Out:
# pandas.Series

# %%
df1.loc[1]  # returns a series
# Out:
# Gold           12
# Silver          9
# Bronze          8
# Continent    Asia
# Name: 1, dtype: object

# %%
df1.loc[[1]]  # returns a dataframe
# Out:
#    Gold  Silver  Bronze Continent
# 1    12       9       8      Asia

# %%
df1.loc[1:3]  # We can slice them too
# Out:
#    Gold  Silver  Bronze Continent
# 1    12       9       8      Asia
# 2    10       5      12      Asia

# %% [markdown]
# **Subsetting rows when labels are used as the label index**
#
# We can use  **```loc['label_based_index']```** to subset the row.
#
# If there are multiple rows, we can use a set of label.
#
# _Note: df2 has strings as the index labels._

# %%
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %%
df2.loc['China']
# Out:
# Gold           12
# Silver          9
# Bronze          8
# Continent    Asia
# Name: China, dtype: object

# %%
df2.loc[['China', 'France']]
# Out:
#         Gold  Silver  Bronze Continent
# China     12       9       8      Asia
# France    15      11       6    Europe

# %% [markdown]
# **What if the dataframe uses string as the label index, but we need to subset many rows out?**
#
# - Do we need to make a list of the countries we want?
# - There are 193 countries in the world, I want the top 50.
# - Typing a list of 50 country names is tedious.
# - We can still subset it by the number using **```iloc[ ]```**.

# %% [markdown]
# If a DataFrame uses strings as its row labels, we can still subset rows by their numerical position using `iloc[]`.
#
# For example, if the rows are countries and we want the first 50:
#
# ```python
# df.iloc[:50]
# ```
#
# `iloc[]` ignores the actual index labels and selects rows by their integer position instead.
#
# So even if the index looks like:
#
# ```text
# Thailand
# Japan
# China
# Germany
# ...
# ```
#
# we do not need to manually create a list of 50 country names. We can simply use:
#
# ```python
# top_50 = df.iloc[:50]
# ```
#
# This selects rows at positions `0` through `49`.

# %%
df2.loc[1:3]  # ERROR. Label is not number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df2.loc[1:3]  # ERROR. Label is not number
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1429, in _LocIndexer._getitem_axis(self, key, axis)
#    1427 if isinstance(key, slice):
#    1428     self._validate_key(key, axis)
# -> 1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
#    1431     return self._getbool_axis(key, axis=axis)
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1461, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1458     return obj.copy(deep=False)
#    1460 labels = obj._get_axis(axis)
# -> 1461 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1463 if isinstance(indexer, slice):
#    1464     return self.obj._slice(indexer, axis=axis)
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6804, in Index.slice_indexer(self, start, end, step)
#    6753 def slice_indexer(
#    6754     self,
#    6755     start: Hashable | None = None,
#    6756     end: Hashable | None = None,
#    6757     step: int | None = None,
#    6758 ) -> slice:
#    6759     """
#    6760     Compute the slice indexer for input labels and step.
#    6761
#    (...)   6802     slice(1, 3, None)
#    6803     """
# -> 6804     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6806     # return a slice
#    6807     if not is_scalar(start_slice):
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7062, in Index.slice_locs(self, start, end, step)
#    7060 start_slice = None
#    7061 if start is not None:
# -> 7062     start_slice = self.get_slice_bound(start, "left")
#    7063 if start_slice is None:
#    7064     start_slice = 0
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6964, in Index.get_slice_bound(self, label, side)
#    6960 original_label = label
#    6962 # For datetime indices label may be a string that has to be converted
#    6963 # to datetime boundary according to its resolution.
# -> 6964 label = self._maybe_cast_slice_bound(label, side)
#    6966 # we need to look up the label
#    6967 try:
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6894, in Index._maybe_cast_slice_bound(self, label, side)
#    6892 # reject them, if index does not contain label
#    6893 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6894     self._raise_invalid_indexer("slice", label)
#    6896 return label
#
# File ~/MUIC/MUIC-ICCS261-Principles-of-Data-Science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:4125, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4123 if reraise is not lib.no_default:
#    4124     raise TypeError(msg) from reraise
# -> 4125 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %%
df2.iloc[1:3]  # iloc saves the day
# Out:
#           Gold  Silver  Bronze Continent
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# ### 2.3 Both rows and columns
# As we just learn that we can use ```iloc[ ]``` to subset data.
#
# We can apply the same method to subset both rows and columns.
#
# Normally, we use indexes to do slicing.
#
# **```df.iloc[row_slicing, column_slicing]```**

# %%
df2.iloc[:, 0:1]  # all rows, first column
# Out:
#           Gold
# France      15
# China       12
# Thailand    10

# %%
df2.iloc[:, 0]
# Out:
# France      15
# China       12
# Thailand    10
# Name: Gold, dtype: int64

# %% [markdown]
# **Prompt**: What is the difference between ```df2.iloc[:, 0:1]``` and ```df2.iloc[:, 0]```?

# %%
print(type(df2.iloc[:, 0:1]), type(df2.iloc[:, 0]))
# Out:
# <class 'pandas.DataFrame'> <class 'pandas.Series'>

# %%
df2.iloc[:, 1:]  # all rows, second column to the end
# Out:
#           Silver  Bronze Continent
# France        11       6    Europe
# China          9       8      Asia
# Thailand       5      12      Asia

# %%
df2.iloc[:, 1:-1]  # all rows, second column to the penultimate column
# Out:
#           Silver  Bronze
# France        11       6
# China          9       8
# Thailand       5      12

# %%
df2.iloc[:2, :]  # first two rows, all columns
# Out:
#         Gold  Silver  Bronze Continent
# France    15      11       6    Europe
# China     12       9       8      Asia

# %%
df2.iloc[:2, [0, 3]]  # first two rows, only the Gold and Continent
# Out:
#         Gold Continent
# France    15    Europe
# China     12      Asia

# %% [markdown]
# ### 2.4 Accessing any particular element
# After we subset a row out, that row is actually a series. Therefore, we can access the element easily by using index.

# %%
x = df2.iloc[2]
x
# Out:
# Gold           10
# Silver          5
# Bronze         12
# Continent    Asia
# Name: Thailand, dtype: object

# %%
type(x)
# Out:
# pandas.Series

# %%
x.iloc[2]  # Let's access the number of Bronze (index )
# Out:
# np.int64(12)

# %%
df2.iloc[2, 2]
# Out:
# np.int64(12)

# %%
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# Extract 5 from df2.

# %%
df2.iloc[2, 1]
# Out:
# np.int64(5)

# %% [markdown]
# ## In-class activity
#
# Complete the activity on Canvas with your group as instructed.

# %% [markdown]
# ## 3 UPDATE
# * 3.1 Change existing value
# * 3.2 Append another dataframe
# * 3.3 Add another column
#
# ### 3.1 Change existing value
# We can update existing value by assigning a new value to it.

# %%
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9       8      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# Updating via position indices

# %%
df2.iloc[1, 2] = 999
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       5      12      Asia

# %% [markdown]
# Updating via labels

# %%
df2.loc['Thailand', 'Silver'] = 8
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %% [markdown]
# ### 3.2 Append another dataframe
# We can use <code>append( )</code> function.

# %%
df2  # For an easy comparison, let's list df2 out again.
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %%
dfplus = pd.DataFrame(
    {
        'Gold': [3],
        'Silver': [2] ,
        'Bronze': [0],
        'Continent': ['Europe']
    },
    ['England'])
dfplus
# Out:
#          Gold  Silver  Bronze Continent
# England     3       2       0    Europe

# %%
df3 = pd.concat([df2, dfplus])
df3
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia
# England      3       2       0    Europe

# %%
df2  # df2 should stay the same.
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %% [markdown]
# ### 3.3 Add another column
# Adding another series is easy. We can assign a new series to a new column label.

# %%
df3["Abbreviation"] = pd.Series(['FR', 'CN', 'TH', 'UK'], index=df3.index)
df3
# Out:
#           Gold  Silver  Bronze Continent Abbreviation
# France      15      11       6    Europe           FR
# China       12       9     999      Asia           CN
# Thailand    10       8      12      Asia           TH
# England      3       2       0    Europe           UK

# %% [markdown]
# ## 4 DELETE
# * 4.1 Delete rows
# * 4.2 Delete columns

# %%
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %% [markdown]
# ### 4.1 Delete rows
# We can use drop( label ) to delete the row.
# Note: drop will return a new dataframe.

# %%
df3 = df2.drop("China")
df3
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# Thailand    10       8      12      Asia

# %%
df2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %% [markdown]
# If we want drop to happen to that dataframe, we can set inplace to True.

# %%
df4 = df2.copy()  # Let's preserve df2 because we are going to delete right into the dataframe.
df4
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %%
df4.drop("China", inplace=True)  # Which axis?
df4
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# Thailand    10       8      12      Asia

# %%
df4_2 = df2.copy()  # Let's preserve df2 because we are going to delete right into the dataframe.
df4_2 = df4_2.drop("China")
df4_2
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# Thailand    10       8      12      Asia

# %%
df5 = df2.drop("Thailand", axis=0)  # row or column?
df5
# Out:
#         Gold  Silver  Bronze Continent
# France    15      11       6    Europe
# China     12       9     999      Asia

# %%
df2  # should remain the same
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %% [markdown]
# ### 4.2 Delete columns
# We can use the same <code>drop( )</code>. This time, we just have to set axis to 1.
#
# (the default is <code>axis=0</code> which means row)

# %%
df6 = df2.copy()
df6
# Out:
#           Gold  Silver  Bronze Continent
# France      15      11       6    Europe
# China       12       9     999      Asia
# Thailand    10       8      12      Asia

# %%
df6.drop("Gold", axis=1, inplace=True)
df6
# Out:
#           Silver  Bronze Continent
# France        11       6    Europe
# China          9     999      Asia
# Thailand       8      12      Asia

# %% [markdown]
# Can we skip the axis argument here?

# %%
df7 = df2.copy()
df7.drop("France", inplace=True)
